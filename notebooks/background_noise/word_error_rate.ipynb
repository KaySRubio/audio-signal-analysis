# %% [markdown]
# # Word Error Rate
# Calculates word error rate when you input the target text and the reference text

# %%
# %pip install jiwer
# Out:
# Looking in indexes: https://nexus.cainc.com/repository/pypi/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 2.1 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 24.2 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from jiwer import wer

# %%
reference = "can make good pets. some dogs can help people too. they do jobs and help people a farm dog is smart it can keeps sheep together in outside it takes them to the barn it keeps the sheep safe. a search dog is it can find things that are  can  it can walk up big rocks. it helps find words it keep people safe outside".lower().replace('.','').replace('?','').replace(',','')
hypothesis = "can make good pets. Some dolls can help people too. They do jobs and help people. A farm doll is marking piece together in a sheep. It says with them outside. It holds them in the marking. It makes the sheep sleep. It takes dogs hungry. It hills white things that are slawed and it can walk up big rock. It helps find doors. It keeps people safe outside.".lower().replace('.','').replace('?','').replace(',','')
print('hypothesis: ', hypothesis)
# Out:
# hypothesis:  can make good pets some dolls can help people too they do jobs and help people a farm doll is marking piece together in a sheep it says with them outside it holds them in the marking it makes the sheep sleep it takes dogs hungry it hills white things that are slawed and it can walk up big rock it helps find doors it keeps people safe outside

# %%
# Sensitive to punctuation and capitalization differences
print(wer(reference, hypothesis))
# Out:
# 0.4153846153846154
